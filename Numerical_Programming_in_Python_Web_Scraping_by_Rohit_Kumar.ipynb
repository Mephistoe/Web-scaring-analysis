# %% [markdown]
# <a href="https://colab.research.google.com/github/Mephistoe/Web-scaring-analysis/blob/main/Numerical_Programming_in_Python_Web_Scraping_by_Rohit_Kumar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Web Scraping & Data Handling Challenge**

# %% [markdown]
# ### **Website:**
# JustWatch -  https://www.justwatch.com/in/movies?release_year_from=2000
#
#
# ### **Description:**
#
# JustWatch is a popular platform that allows users to search for movies and TV shows across multiple streaming services like Netflix, Amazon Prime, Hulu, etc. For this assignment, you will be required to scrape movie and TV show data from JustWatch using Selenium, Python, and BeautifulSoup. Extract data from HTML, not by directly calling their APIs. Then, perform data filtering and analysis using Pandas, and finally, save the results to a CSV file.
#
# ### **Tasks:**
#
# **1. Web Scraping:**
#
# Use BeautifulSoup to scrape the following data from JustWatch:
#
#    **a. Movie Information:**
#
#       - Movie title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the movie page on JustWatch
#
#    **b. TV Show Information:**
#
#       - TV show title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the TV show page on JustWatch
#
#   **c. Scope:**
#
# ```
#  ` - Scrape data for at least 50 movies and 50 TV shows.
#    - You can choose the entry point (e.g., starting with popular movies,
#      or a specific genre, etc.) to ensure a diverse dataset.`
#
# ```
#
#
# **2. Data Filtering & Analysis:**
#
#    After scraping the data, use Pandas to perform the following tasks:
#
#    **a. Filter movies and TV shows based on specific criteria:**
#
#    ```
#       - Only include movies and TV shows released in the last 2 years (from the current date).
#       - Only include movies and TV shows with an IMDb rating of 7 or higher.
# ```
#
#    **b. Data Analysis:**
#
#    ```
#       - Calculate the average IMDb rating for the scraped movies and TV shows.
#       - Identify the top 5 genres that have the highest number of available movies and TV shows.
#       - Determine the streaming service with the most significant number of offerings.
#
#    ```
#
# **3. Data Export:**
#
# ```
#    - Dump the filtered and analysed data into a CSV file for further processing and reporting.
#
#    - Keep the CSV file in your Drive Folder and Share the Drive link on the colab while keeping view access with anyone.
# ```
#
# **Submission:**
# ```
# - Submit a link to your Colab made for the assignment.
#
# - The Colab should contain your Python script (.py format only) with clear
#   comments explaining the scraping, filtering, and analysis process.
#
# - Your Code shouldn't have any errors and should be executable at a one go.
#
# - Before Conclusion, Keep your Dataset Drive Link in the Notebook.
# ```
#
#
#
# **Note:**
#
# 1. Properly handle errors and exceptions during web scraping to ensure a robust script.
#
# 2. Make sure your code is well-structured, easy to understand, and follows Python best practices.
#
# 3. The assignment will be evaluated based on the correctness of the scraped data, accuracy of data filtering and analysis, and the overall quality of the Python code.

# %% [markdown]
# # **Start The Project**

# %% [markdown]
# ## **Task 1:- Web Scrapping**

# %%
#Installing all necessary labraries
# !pip install bs4
# !pip install requests

# %%
#import all necessary labraries
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Scrapping Movies Data**

# %%
def fetch_movie_urls(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
    }
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return "Failed to retrieve the page, status code:", response.status_code
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup


url = 'https://www.justwatch.com/in/movies?release_year_from=2000'
soup=fetch_movie_urls(url)
print(soup.prettify())

## Hint : Use the following code to extract the film urls
# movie_links = soup.find_all('a', href=True)
# movie_urls = [link['href'] for link in movie_links if '/movie/' in link['href']]

# url_list=[]
# for x in movie_urls:
#   url_list.append('https://www.justwatch.com'+x)
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
# ...

# %% [markdown]
# ## **Fetching Movie URL's**

# %%
# Write Your Code here
movie_links = soup.find_all('a', href=True)
movie_urls = [link['href'] for link in movie_links if '/movie/' in link['href']]

movie_url=[]
for x in movie_urls:
  movie_url.append('https://www.justwatch.com'+x)

# %%
movie_url
# Out:
# ['https://www.justwatch.com/in/movie/maharaja-2024',
#  'https://www.justwatch.com/in/movie/kill-2024',
#  'https://www.justwatch.com/in/movie/project-k',
#  'https://www.justwatch.com/in/movie/munjha',
#  'https://www.justwatch.com/in/movie/the-gangster-the-cop-the-devil',
#  'https://www.justwatch.com/in/movie/aadujeevitham',
#  'https://www.justwatch.com/in/movie/kingdom-of-the-planet-of-the-apes',
#  'https://www.justwatch.com/in/movie/aavesham-2024',
#  'https://www.justwatch.com/in/movie/family-star',
#  'https://www.justwatch.com/in/movie/deadpool-3',
#  'https://www.justwatch.com/in/movie/the-fall-guy',
#  'https://www.justwatch.com/in/movie/furiosa',
#  'https://www.justwatch.com/in/movie/deadpool',
#  'https://www.justwatch.com/in/movie/maharshi',
#  'https://www.justwatch.com/in/movie/harom-hara',
#  'https://www.justwatch.com/in/movie/sri-2023',
#  'https://www.justwatch.com/in/movie/dune-part-two',
#  'https://www.justwatch.com/in/movie/garudan-2024',
# ...

# %% [markdown]
# ## **Scrapping Movie Title**

# %%
# Write Your Code here
import time
movie_title = []
for url in movie_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')
    title = soup.find_all('div',attrs={'class':'title-detail-hero__details'})[0].find_all('h1')[0].text
  except:
    title = "NA"
  movie_title.append(title)
  time.sleep(2)
print(movie_title)
print(len(movie_title))
# Out:
# [' Maharaja (2024)', ' Kill (2024)', ' Kalki 2898-AD (2024)', ' Munjya (2024)', ' The Gangster, the Cop, the Devil (2019)', ' The Goat Life (2024)', ' Kingdom of the Planet of the Apes (2024)', ' Aavesham (2024)', ' Family Star (2024)', ' Deadpool & Wolverine (2024)', ' The Fall Guy (2024)', ' Furiosa: A Mad Max Saga (2024)', ' Deadpool (2016)', ' Maharshi (2019)', ' Harom Hara (2024)', ' Srikanth (2024)', ' Dune: Part Two (2024)', ' Garudan (2024)', ' Bad Boys: Ride or Die (2024)', ' Chandu Champion (2024)', ' Inside Out (2015)', ' Kung Fu Panda 4 (2024)', ' The Ministry of Ungentlemanly Warfare (2024)', ' 365 Days (2020)', ' Godzilla x Kong: The New Empire (2024)', ' Agent (2023)', ' Manjummel Boys (2024)', ' Laapataa Ladies (2024)', ' Je Jatt Vigarh Gya (2024)', ' Bhaiyya Ji (2024)', ' Oppenheimer (2023)', ' Civil War (2024)', ' Maharaj (2024)', ' Mr. & Mrs. Mahi (2024)', ' Hit Man (2024)', ' Wild Wild Punjab (2024)', ' Dune (2021)', ' A Quiet Place: Day One (2024)', ' Stree (2018
# ...

# %% [markdown]
# ## **Scrapping release Year**

# %%
# Write Your Code here
import time
release_year = []
for url in movie_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url,headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')
    year = eval(soup.find_all('div',attrs={'class':'title-detail-hero__details'})[0].find_all('span')[0].text.strip())
  except:
    year = 'NA'
  release_year.append(year)
  time.sleep(3)
print(release_year)
print(len(release_year))
# Out:
# [2024, 2024, 2024, 2024, 2019, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2016, 2019, 2024, 2024, 2024, 2024, 2024, 2024, 2015, 2024, 2024, 2020, 2024, 2023, 2024, 2024, 2024, 2024, 2023, 2024, 2024, 2024, 2024, 2024, 2021, 2024, 2018, 2023, 2023, 2024, 2009, 2024, 2018, 2024, 2024, 2023, 2024, 2024, 2023, 2024, 2023, 2024, 2023, 2011, 2018, 2024, 2024, 2024, 2024, 2022, 2014, 2018, 2024, 2015, 2001, 2024, 2023, 2023, 2022, 2023, 2024, 2024, 2022, 2013, 2011, 2024, 2018, 2024, 2018, 2024, 2009, 2024, 2024, 2000, 2018, 2022, 2023, 2016, 2024, 2010, 2023, 2016, 2021, 2024, 2024, 2024, 2024, 2014, 2024, 2024, 2024, 2024, 2019, 2024, 2024, 2024, 2024, 2024]
# 110

# %% [markdown]
# ## **Scrapping Genres**

# %%
# Write Your Code here
import time
genre_list = []
for url in movie_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')
    for x in soup.find_all('div',attrs={'class':'detail-infos'}):
      if x.find_all('h3',attrs={'class':'detail-infos__subheading'})[0].text=='Genres':
        genres = x.find_all('div',attrs={'class':'detail-infos__value'})[0].text
  except:
    genres = 'NA'
  genre_list.append(genres)
  time.sleep(3)
print(genre_list)
print(len(genre_list))
# Out:
# ['Crime, Drama, Mystery & Thriller, Action & Adventure', 'Mystery & Thriller, Action & Adventure, Crime, Drama', 'Fantasy, Science-Fiction, Drama, Action & Adventure, Mystery & Thriller', 'Comedy, Horror', 'Crime, Action & Adventure, Mystery & Thriller', 'Drama', 'Action & Adventure, Science-Fiction, Drama, Mystery & Thriller', 'Comedy, Action & Adventure', 'Action & Adventure, Drama, Comedy, Romance', 'Science-Fiction, Action & Adventure, Comedy', 'Romance, Action & Adventure, Comedy, Drama', 'Action & Adventure, Science-Fiction, Mystery & Thriller', 'Action & Adventure, Comedy', 'Action & Adventure, Drama', 'Drama, Action & Adventure, Crime', 'Drama', 'Science-Fiction, Action & Adventure, Drama', 'Action & Adventure, Crime, Mystery & Thriller', 'Comedy, Mystery & Thriller, Crime, Action & Adventure', 'Action & Adventure, Drama, History, Sport, War & Military', 'Drama, Comedy, Animation, Kids & Family, Fantasy', 'Kids & Family, Fantasy, Animation, Action & Adventure, Comedy', 'Actio
# ...

# %% [markdown]
# ## **Scrapping IMBD Rating**

# %%
# Write Your Code here
import time
imdb_rating = []
for url in movie_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')
    for x in soup.find_all('div',attrs={'class':'detail-infos'}):
      if x.find_all('h3',attrs={'class':'detail-infos__subheading'})[0].text=='Rating':
        rating = x.find_all('div',attrs={'class':'detail-infos__value'})[0].text.strip()
  except:
    rating = 'NA'
  imdb_rating.append(rating)
  time.sleep(3)
print(imdb_rating)
print(len(imdb_rating))
# Out:
# ['8.7  (31k)', '8.7  (31k)', '8.7  (31k)', '8.7  (31k)', '6.9  (24k)', '8.2  (12k)', '7.0  (86k)', '7.9  (17k)', '5.3  (4k)', '5.3  (4k)', '5.3  (4k)', '5.3  (4k)', '8.0  (1m)', '7.2  (9k)', '8.2  (2k)', '7.5  (10k)', '8.5  (488k)', '7.2  (2k)', '7.2  (2k)', '7.2  (2k)', '8.1  (816k)', '6.3  (49k)', '6.8  (70k)', '3.3  (99k)', '3.3  (99k)', '3.3  (99k)', '8.3  (19k)', '8.5  (37k)', '8.5  (37k)', '5.3  (6k)', '8.3  (776k)', '7.1  (141k)', '6.5  (10k)', '6.1  (13k)', '6.9  (74k)', '6.6  (13k)', '8.0  (892k)', '8.0  (892k)', '7.5  (39k)', '7.7  (140k)', '6.2  (95k)', '6.7  (35k)', '6.7  (35k)', '6.7  (35k)', '7.6  (665k)', '6.6  (17k)', '6.6  (2k)', '8.9  (124k)', '8.1  (16k)', '7.7', '7.4  (104k)', '7.5  (5k)', '6.5  (67k)', '6.5  (67k)', '7.9  (52k)', '7.8  (50k)', '7.7  (5k)', '7.8  (25k)', '7.9  (13k)', '5.2  (1k)', '7.4  (1k)', '7.0  (157k)', '5.0  (12k)', '7.3  (388k)', '6.1  (63k)', '8.1  (1m)', '7.6  (865k)', '7.6  (865k)', '7.7  (17k)', '7.8  (25k)', '8.1  (16k)', '7.0  (98k)',
# ...

# %% [markdown]
# ## **Scrapping Runtime/Duration**

# %%
# Write Your Code here
import time
movie_runtime = []
for url in movie_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')
    for x in soup.find_all('div',attrs={'class':"detail-infos"}):
       if x.find_all('h3',attrs = {'class':'detail-infos__subheading'})[0].text == 'Runtime':
          Runtime = x.find_all('div',attrs={'class':'detail-infos__value'})[0].text

  except:
    Runtime = "NA"
  movie_runtime.append(Runtime)
  time.sleep(2)
print(movie_runtime)
print(len(movie_runtime))
# Out:
# ['2h 30min', '1h 45min', '3h 1min', '2h 3min', '1h 50min', '2h 51min', '2h 25min', '2h 38min', '2h 39min', '2h 8min', '2h 6min', '2h 29min', '1h 48min', '2h 56min', '2h 34min', '2h 14min', '2h 47min', '2h 13min', '1h 55min', '2h 22min', '1h 35min', '1h 34min', '2h 0min', '1h 54min', '1h 55min', '2h 34min', '2h 15min', '2h 2min', '2h 12min', '2h 30min', '3h 0min', '1h 49min', '2h 12min', '2h 19min', '1h 56min', '1h 51min', '2h 35min', '1h 39min', '2h 8min', '2h 4min', '3h 24min', '1h 44min', '1h 38min', '1h 37min', '2h 0min', '2h 3min', '2h 12min', '2h 26min', '3h 1min', '2h 3min', '1h 45min', '2h 0min', '2h 55min', '1h 41min', '2h 4min', '2h 39min', '2h 19min', '2h 39min', '2h 36min', '2h 28min', '2h 28min', '1h 47min', '1h 45min', '2h 8min', '1h 55min', '2h 0min', '2h 32min', '2h 12min', '2h 30min', '2h 5min', '2h 52min', '2h 49min', '2h 12min', '2h 19min', '3h 9min', '3h 0min', '1h 30min', '2h 14min', '1h 53min', '2h 40min', '1h 31min', '1h 57min', '2h 34min', '1h 33min', '2h 23min
# ...

# %% [markdown]
# ## **Scrapping Age Rating**

# %%
# Write Your Code here
import time

Age_list = []
for url in movie_url:
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }
        data = requests.get(url, headers=headers)
        soup = BeautifulSoup(data.text, 'html.parser')
        Age = "NA"  # Default value in case 'Age rating' is not found

        for x in soup.find_all('div', attrs={'class': "detail-infos"}):
            subheading = x.find_all('h3', attrs={'class': 'detail-infos__subheading'})
            if subheading and subheading[0].text == 'Age rating':
                Age = x.find_all('div', attrs={'class': 'detail-infos__value'})[0].text
                break  # Found the age rating, exit the loop

    except Exception as e:
        print(f"Error occurred for URL {url}: {e}")
        Age = "NA"

    Age_list.append(Age)
    time.sleep(2)

print(Age_list)
print(len(Age_list))
# Out:
# ['NA', 'A', 'UA', 'NA', 'NA', 'UA', 'NA', 'NA', 'NA', 'A', 'UA', 'A', 'A', 'UA', 'A', 'U', 'NA', 'UA', 'NA', 'UA', 'U', 'U', 'NA', 'NA', 'UA', 'UA', 'UA', 'UA', 'NA', 'NA', 'UA', 'NA', 'NA', 'U', 'A', 'NA', 'UA', 'NA', 'UA', 'NA', 'A', 'NA', 'A', 'U', 'A', 'UA', 'NA', 'NA', 'NA', 'U', 'UA', 'UA', 'A', 'A', 'NA', 'UA', 'UA', 'UA', 'U', 'NA', 'A', 'A', 'NA', 'A', 'NA', 'A', 'U', 'A', 'UA', 'NA', 'U', 'UA', 'UA', 'UA', 'A', 'A', 'NA', 'UA', 'A', 'NA', 'A', 'NA', 'U', 'NA', 'UA', 'NA', 'UA', 'UA', 'A', 'UA', 'UA', 'NA', 'A', 'A', 'UA', 'UA', 'NA', 'U', 'UA', 'NA', 'NA', 'A', 'UA', 'NA', 'NA', 'A', 'NA', 'NA', 'NA', 'NA']
# 110

# %% [markdown]
# ## **Fetching Production Countries Details**

# %%
# Write Your Code here
import time
movie_production_country = []
for url in movie_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')

    for x in soup.find_all('div',attrs = {'class':'detail-infos'}):
      if x.find_all('h3',attrs={'class':'detail-infos__subheading'})[0].text ==' Production country ':
         country = x.find_all('div',attrs = {'class':'detail-infos__value'})[0].text

  except:
    country = "NA"
  movie_production_country.append(country)
  time.sleep(2)
print(movie_production_country)
print(len(movie_production_country))
# Out:
# ['India', 'India, United States', 'India', 'India', 'South Korea', 'India, United States', 'United States', 'India', 'India', 'United States', 'Canada, United States, Australia', 'United States, Australia', 'United States', 'India', 'India', 'India', 'United States', 'India', 'United States', 'India', 'United States', 'United States', 'United States, United Kingdom, Turkey', 'Poland', 'Australia, United States', 'India', 'India', 'India', 'India', 'India', 'United Kingdom, United States', 'United Kingdom, United States', 'India', 'India', 'United States', 'India', 'United States', 'United Kingdom, Canada, United States', 'India', 'Japan', 'India', 'United Kingdom, United States', 'United Kingdom, Australia', 'United States', 'United States', 'India', 'India', 'India', 'India', 'India', 'Poland, United Kingdom, United States', 'India', 'India', 'United States, Canada', 'Germany, Japan', 'India', 'India', 'India', 'India', 'India', 'India', 'United States', 'United States', 'United Sta
# ...

# %% [markdown]
# ## **Fetching Streaming Service Details**

# %%
# Write Your Code here
Movie_Streaming_Provider =[]
import time
for url in movie_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,"html.parser")

    Stream_provider = soup.find("div",attrs ={'class':'buybox'}).find_all("img",attrs={'class':'offer__icon'})
    alt_values = [img['alt'] for img in Stream_provider]
    alt_values = (",".join(alt_values))

  except :
    alt_values = 'NA'
  Movie_Streaming_Provider.append(alt_values)
  time.sleep(3)


print(Movie_Streaming_Provider)
print(len(Movie_Streaming_Provider))
# Out:
# ['Netflix,Apple TV+,Bookmyshow', 'Apple TV+', 'Apple TV+,Bookmyshow', 'Apple TV+,Bookmyshow', 'Lionsgate Play,Apple TV+', 'Netflix,Apple TV+', 'Hotstar,Apple TV+,Apple TV', 'Amazon Prime Video,Hotstar,Apple TV+,Amazon Video', 'Amazon Prime Video,Jio Cinema,Apple TV+,Amazon Video,Bookmyshow', 'Apple TV+,Bookmyshow', 'Apple TV+,Zee5,Amazon Video,Apple TV,Apple TV', 'Apple TV+,Apple TV', 'Hotstar,Apple TV+,Amazon Video,Apple TV,Apple TV', 'Amazon Prime Video,Apple TV+,Hotstar,Amazon Video', 'Amazon Prime Video,Jio Cinema,aha,Apple TV+', 'Netflix,Apple TV+', 'Jio Cinema,Apple TV+,Amazon Video,Apple TV,Apple TV', 'Amazon Prime Video,Apple TV+,Amazon Video', 'Apple TV+,Zee5,Amazon Video,Apple TV,Apple TV', 'Apple TV+,Amazon Video,Bookmyshow', 'Hotstar,Crunchyroll,Tata Play,Apple TV,Apple TV', 'Jio Cinema,Crunchyroll,Zee5,Amazon Video,Apple TV,Apple TV,Bookmyshow', 'Amazon Prime Video,Apple TV+', 'Netflix,Apple TV+', 'Apple TV+,Amazon Video,Apple TV,Apple TV', 'Apple TV+', 'Hotstar,Apple TV
# ...

# %% [markdown]
# ## **Now Creating Movies DataFrame**

# %%
# Write Your Code here
info = {
    'movies_title': movie_title,
    'movies_year' : release_year,
    'movies_genre' : genre_list,
    'movies_imdb_rating':imdb_rating,
    'movies_runtime' : movie_runtime,
    'production_country' : movie_production_country,
    'streaming_service' : Movie_Streaming_Provider,
    'movie_link': movie_url
}
movie_df = pd.DataFrame(info)

# %%
movie_df
# Out:
#                                  movies_title  movies_year  \
# 0                             Maharaja (2024)         2024
# 1                                 Kill (2024)         2024
# 2                        Kalki 2898-AD (2024)         2024
# 3                               Munjya (2024)         2024
# 4     The Gangster, the Cop, the Devil (2019)         2019
# ..                                        ...          ...
# 105                    The Instigators (2024)         2024
# 106                          Daughters (2024)         2024
# 107                          The Union (2024)         2024
# 108                         Nice Girls (2024)         2024
# 109         Secret Lives of Orangutans (2024)         2024
#
#                                           movies_genre movies_imdb_rating  \
# 0    Crime, Drama, Mystery & Thriller, Action & Adv...         8.7  (31k)
# 1    Mystery & Thriller, Action & Adventure, Crime,...         8.7  (31k)
# ...

# %%
# make a csv file
movie_df.to_csv('movie_df.csv')

Datasets_Drive_Link ='https://drive.google.com/drive/folders/1hiIwJxY86Y-fDFB7mPYN2m5h10fJH-zo?usp=sharing'

# %% [markdown]
# [movie_df](https://drive.google.com/file/d/1xc6gOS56C9UE7SuDcfMjeKMQ342IiC44/view?usp=sharing)

# %% [markdown]
# ## **Scraping TV  Show Data**

# %%
# Specifying the URL from which movies related data will be fetched
url='https://www.justwatch.com/in/tv-shows?release_year_from=2000'

# WAS GETTING 403 ERROR, so took help online and found this piece of code so that it wont throw 403 error
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}

# Sending an HTTP GET request to the URL
page=requests.get(url, headers= headers)

# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(page.text,'html.parser')

# Printing the prettified HTML content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
# ...

# %% [markdown]
# ## **Fetching Tv shows Url details**

# %%
# Write Your Code here
# fetch all the link of 100 movies
tv_show_url = []

for x in soup.find_all('a',attrs={'class':'title-list-grid__item--link'}):
  tv_show_url.append('https://www.justwatch.com'+x['href'])
print(tv_show_url)
print(len(tv_show_url))
# Out:
# ['https://www.justwatch.com/in/tv-show/mirzapur', 'https://www.justwatch.com/in/tv-show/house-of-the-dragon', 'https://www.justwatch.com/in/tv-show/the-boys', 'https://www.justwatch.com/in/tv-show/panchayat', 'https://www.justwatch.com/in/tv-show/sweet-home', 'https://www.justwatch.com/in/tv-show/game-of-thrones', 'https://www.justwatch.com/in/tv-show/apharan', 'https://www.justwatch.com/in/tv-show/demon-slayer-kimetsu-no-yaiba', 'https://www.justwatch.com/in/tv-show/shogun-2024', 'https://www.justwatch.com/in/tv-show/the-bear', 'https://www.justwatch.com/in/tv-show/evil', 'https://www.justwatch.com/in/tv-show/presumed-innocent', 'https://www.justwatch.com/in/tv-show/tribhuvan-mishra-ca-topper', 'https://www.justwatch.com/in/tv-show/bigg-boss-ott', 'https://www.justwatch.com/in/tv-show/y-the-last-man', 'https://www.justwatch.com/in/tv-show/gullak', 'https://www.justwatch.com/in/tv-show/elite', 'https://www.justwatch.com/in/tv-show/paperhouse', 'https://www.justwatch.com/in/tv-show/at
# ...

# %% [markdown]
# ## **Fetching Tv Show Title details**

# %%
# Write Your Code here
import time
tv_shows_title = []
for url in tv_show_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')
    title = soup.find_all('div',attrs={'class':'title-detail-hero__details'})[0].find_all('h1')[0].text
  except:
    title = "NA"
  tv_shows_title.append(title)
  time.sleep(2)
print(tv_shows_title)
# Out:
# [' Mirzapur (2018)', ' House of the Dragon (2022)', ' The Boys (2019)', ' Panchayat (2020)', ' Sweet Home (2020)', ' Game of Thrones (2011)', ' Apharan (2018)', ' Demon Slayer: Kimetsu no Yaiba (2019)', ' Shōgun (2024)', ' The Bear (2022)', ' Evil (2019)', ' Presumed Innocent (2024)', ' Tribhuvan Mishra CA Topper (2024)', ' Bigg Boss OTT (2021)', ' Y: The Last Man (2021)', ' Gullak (2019)', ' Elite (2018)', ' Money Heist (2017)', ' Attack on Titan (2013)', ' XXX: Uncensored (2018)', ' Kota Factory (2019)', ' Mastram (2020)', ' Aashram (2020)', ' Batman: Caped Crusader (2024)', ' Breaking Bad (2008)', ' Bigg Boss (2006)', ' Raising Voices (2024)', ' College Romance (2018)', ' Stranger Things (2016)', ' The Rookie (2018)', ' Asur: Welcome to Your Dark Side (2020)', ' Fallout (2024)', ' Cobra Kai (2018)', ' Those About to Die (2024)', ' 36 Days (2024)', ' The Family Man (2019)', ' The Flash (2014)', ' Dark (2017)', ' La Brea (2021)', ' Farzi (2023)', ' 3 Body Problem (2024)', ' Westworl
# ...

# %% [markdown]
# ## **Fetching Release Year**

# %%
# Write Your Code here
import time
tv_shows_year = []
for url in tv_show_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url,headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')
    year = eval(soup.find_all('div',attrs={'class':'title-detail-hero__details'})[0].find_all('span')[0].text.strip())
  except:
    year = 'NA'
  tv_shows_year.append(year)
  time.sleep(3)
print(tv_shows_year)
# Out:
# [2018, 2022, 2019, 2020, 2020, 2011, 2018, 2019, 2024, 2022, 2019, 2024, 2024, 2021, 2021, 2019, 2018, 2017, 2013, 2018, 2019, 2020, 2020, 2024, 2008, 2006, 2024, 2018, 2016, 2018, 2020, 2024, 2018, 2024, 2024, 2019, 2014, 2017, 2021, 2023, 2024, 2016, 2007, 2024, 2020, 2021, 2020, 2017, 2024, 2014, 2024, 2014, 2008, 2018, 2021, 2018, 2020, 2024, 2020, 2013, 2010, 2011, 2022, 2024, 2022, 2017, 2021, 2002, 2005, 2013, 2024, 2019, 2013, 2024, 2021, 2024, 2007, 2014, 2024, 2022, 2004, 2020, 2020, 2022, 2005, 2010, 2009, 2023, 2018, 2023, 2005, 2022, 2024, 2024, 2009, 2024, 2002, 2016, 2020, 2018]

# %% [markdown]
# ## **Fetching TV Show Genre Details**

# %%
# Write Your Code here
tv_genre_list = []
for url in tv_show_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')
    for x in soup.find_all('div',attrs={'class':'detail-infos'}):
      if x.find_all('h3',attrs={'class':'detail-infos__subheading'})[0].text=='Genres':
        genres = x.find_all('div',attrs={'class':'detail-infos__value'})[0].text
  except:
    genres = 'NA'
  tv_genre_list.append(genres)
  time.sleep(3)
print(tv_genre_list)
# Out:
# ['Action & Adventure, Drama, Crime, Mystery & Thriller', 'Drama, Action & Adventure, Science-Fiction, Fantasy, Romance', 'Action & Adventure, Science-Fiction, Comedy, Crime, Drama', 'Comedy, Drama', 'Science-Fiction, Fantasy, Horror, Mystery & Thriller, Drama', 'Fantasy, Action & Adventure, Drama, Science-Fiction', 'Drama, Action & Adventure, Crime, Mystery & Thriller', 'Science-Fiction, Animation, Action & Adventure, Fantasy, Mystery & Thriller', 'War & Military, Drama, History', 'Drama, Comedy', 'Mystery & Thriller, Crime, Drama, Horror', 'Drama, Crime', 'Mystery & Thriller, Comedy, Crime, Drama', 'Reality TV', 'Science-Fiction, Action & Adventure, Drama', 'Comedy, Drama, Kids & Family', 'Drama, Crime, Mystery & Thriller', 'Drama, Mystery & Thriller, Action & Adventure, Crime, Made in Europe', 'Drama, Fantasy, Horror, Animation, Action & Adventure, Science-Fiction', 'Comedy, Drama, Romance', 'Comedy, Drama', 'Drama, Comedy, Fantasy', 'Drama, Crime, Mystery & Thriller', 'Action & Ad
# ...

# %% [markdown]
# ## **Fetching IMDB Rating Details**

# %%
# Write Your Code here
import time
tv_imdb_rating = []
for url in tv_show_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')
    for x in soup.find_all('div',attrs={'class':'detail-infos'}):
      if x.find_all('h3',attrs={'class':'detail-infos__subheading'})[0].text=='Rating':
        rating = x.find_all('div',attrs={'class':'detail-infos__value'})[0].text.strip()
  except:
    rating = 'NA'
  tv_imdb_rating.append(rating)
  time.sleep(3)
print(tv_imdb_rating)
# Out:
# ['8.5  (86k)', '8.4  (422k)', '8.7  (703k)', '9.0  (95k)', '7.3  (33k)', '9.2  (2m)', '8.2  (20k)', '8.6  (160k)', '8.7  (158k)', '8.6  (235k)', '7.8  (39k)', '7.8  (29k)', '7.0  (1k)', '7.0  (1k)', '7.0  (1k)', '9.1  (23k)', '7.2  (92k)', '8.2  (541k)', '9.1  (535k)', '4.8', '9.0  (84k)', '9.0  (84k)', '9.0  (84k)', '7.5  (3k)', '9.5  (2m)', '9.5  (2m)', '7.2  (3k)', '8.3  (28k)', '8.7  (1m)', '8.7  (1m)', '8.5  (66k)', '8.4  (235k)', '8.5  (209k)', '6.5  (8k)', '4.7', '8.7  (100k)', '7.5  (370k)', '8.7  (454k)', '5.8  (17k)', '8.4  (47k)', '7.5  (134k)', '8.5  (537k)', '8.7  (263k)', '8.7  (263k)', '7.4  (190k)', '8.3  (2k)', '7.3  (12k)', '8.0  (117k)', '6.4', '8.9  (427k)', '7.7  (35k)', '8.9  (665k)', '8.9  (665k)', '3.4  (3k)', '8.2  (51k)', '7.7  (306k)', '8.6  (125k)', '6.2', '9.3  (150k)', '6.5  (113k)', '8.1  (1m)', '8.1  (1m)', '7.3  (61k)', '6.8  (3k)', '6.8  (3k)', '7.7  (114k)', '9.1  (12k)', '8.4  (131k)', '8.3  (736k)', '8.5  (592k)', '6.4  (27k)', '8.3  (250k)', '8.8
# ...

# %% [markdown]
# ## **Fetching Age Rating Details**

# %%
# Write Your Code here
import time

Tv_Age_list = []
for url in tv_show_url:
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.9',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }
        data = requests.get(url, headers=headers)
        soup = BeautifulSoup(data.text, 'html.parser')
        Age = "NA"  # Default value in case 'Age rating' is not found

        for x in soup.find_all('div', attrs={'class': "detail-infos"}):
            subheading = x.find_all('h3', attrs={'class': 'detail-infos__subheading'})
            if subheading and subheading[0].text == 'Age rating':
                Age = x.find_all('div', attrs={'class': 'detail-infos__value'})[0].text
                break  # Found the age rating, exit the loop

    except Exception as e:
        print(f"Error occurred for URL {url}: {e}")
        Age = "NA"

    Tv_Age_list.append(Age)
    time.sleep(2)

print(Tv_Age_list)
print(len(Tv_Age_list))
# Out:
# ['A', 'A', 'A', 'NA', 'A', 'A', 'NA', 'NA', 'NA', 'NA', 'NA', 'A', 'NA', 'A', 'A', 'NA', 'A', 'NA', 'UA', 'NA', 'NA', 'NA', 'NA', 'NA', 'U', 'NA', 'NA', 'A', 'NA', 'NA', 'NA', 'A', 'A', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'A', 'A', 'U', 'NA', 'A', 'UA', 'NA', 'U', 'NA', 'U', 'A', 'U', 'U', 'A', 'NA', 'A', 'NA', 'NA', 'NA', 'NA', 'U', 'U', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'U', 'U', 'NA', 'A', 'A', 'NA', 'A', 'NA', 'U', 'NA', 'NA', 'A', 'U', 'NA', 'A', 'NA', 'U', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'U', 'NA', 'NA']
# 100

# %% [markdown]
# ## **Fetching Production Country details**

# %%
# Write Your Code here
import time
tv_production_country = []
for url in tv_show_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')

    for x in soup.find_all('div',attrs = {'class':'detail-infos'}):
      if x.find_all('h3',attrs={'class':'detail-infos__subheading'})[0].text ==' Production country ':
         country = x.find_all('div',attrs = {'class':'detail-infos__value'})[0].text

  except:
    country = "NA"
  tv_production_country.append(country)
  time.sleep(2)
print(tv_production_country)
print(len(tv_production_country))
# Out:
# ['India', 'United States', 'United States', 'India', 'South Korea', 'United States, United Kingdom', 'India', 'Japan', 'United States', 'United States', 'United States', 'United States', 'India', 'India', 'United States', 'India', 'Spain', 'Spain', 'Japan', 'India', 'India', 'India', 'India', 'United States', 'United States', 'India', 'Spain', 'India', 'United States', 'United States', 'India', 'United States', 'United States', 'United States, Germany, Italy', 'India', 'India', 'United States', 'Germany', 'United States', 'India', 'United States', 'United States', 'United States', 'India', 'United States', 'India', 'United States', 'United States', 'Japan', 'United States', 'United States', 'United States', 'India', 'India', 'United States', 'United States', 'United States, Japan', 'Thailand', 'India', 'United States', 'United States', 'United States', 'United States', 'United Kingdom', 'United States', 'United States', 'India', 'Japan', 'United States', 'Canada', 'India', 'United St
# ...

# %% [markdown]
# ## **Fetching Streaming Service details**

# %%
# Write Your Code here
tv_Streaming_Provider =[]
import time
for url in tv_show_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,"html.parser")
    Stream_provider = soup.find("div",attrs ={'class':'buybox-row__offers'}).find_all("img",attrs={'class':'offer__icon'})
    alt_values = [img['alt'] for img in Stream_provider]
    alt_values = (",".join(alt_values))

  except:
    alt_values = 'NA'
  tv_Streaming_Provider.append(alt_values)
  time.sleep(3)


print(tv_Streaming_Provider)
# Out:
# ['Amazon Prime Video', 'Jio Cinema', 'Amazon Prime Video', 'Amazon Prime Video', 'Netflix', 'Jio Cinema', 'Jio Cinema,Alt Balaji', 'Crunchyroll', 'Hotstar', 'Hotstar', 'Jio Cinema', 'Apple TV Plus', 'Netflix', 'Jio Cinema', 'NA', 'Sony Liv', 'Netflix', 'Netflix', 'Amazon Prime Video', 'Alt Balaji', 'Netflix', 'NA', 'MX Player', 'Amazon Prime Video', 'Netflix', 'NA', 'Netflix', 'Sony Liv', 'Netflix', 'NA', 'Jio Cinema', 'Amazon Prime Video', 'Netflix', 'Amazon Prime Video', 'Sony Liv', 'Amazon Prime Video', 'Amazon Prime Video', 'Netflix', 'Jio Cinema', 'Amazon Prime Video', 'Netflix', 'Jio Cinema', 'Netflix,Lionsgate Play,Lionsgate Play Apple TV Channel,Lionsgate Play Amazon Channel', 'MX Player,Amazon miniTV', 'Netflix', 'Zee5,VI movies and tv', 'Netflix', 'Amazon Prime Video', 'Hotstar', 'Amazon Prime Video', 'Apple TV Plus', 'Jio Cinema', 'Jio Cinema', 'Alt Balaji', 'Amazon Prime Video', 'Netflix', 'Amazon Prime Video,Crunchyroll', 'Netflix', 'Sony Liv', 'Amazon Prime Video', 'Ama
# ...

# %% [markdown]
# ## **Fetching Duration Details**

# %%
# Write Your Code here
import time
tv_runtime = []
for url in tv_show_url:
  try:
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
}
    data = requests.get(url, headers = headers)
    soup = BeautifulSoup(data.text,'html.parser')
    for x in soup.find_all('div',attrs={'class':"detail-infos"}):
       if x.find_all('h3',attrs = {'class':'detail-infos__subheading'})[0].text == 'Runtime':
          Runtime = x.find_all('div',attrs={'class':'detail-infos__value'})[0].text

  except:
    Runtime = "NA"
  tv_runtime.append(Runtime)
  time.sleep(2)
print(tv_runtime)
print(len(tv_runtime))
# Out:
# ['50min', '1h 2min', '1h 1min', '35min', '58min', '58min', '24min', '26min', '59min', '34min', '49min', '43min', '57min', '1h 30min', '51min', '30min', '49min', '50min', '25min', '22min', '43min', '28min', '43min', '25min', '47min', '1h 16min', '46min', '31min', '1h 1min', '42min', '47min', '59min', '34min', '53min', '37min', '45min', '45min', '56min', '42min', '56min', '56min', '1h 1min', '49min', '32min', '1h 1min', '39min', '46min', '43min', '47min', '52min', '52min', '1h 1min', '45min', '44min', '47min', '48min', '24min', '51min', '52min', '43min', '46min', '44min', '49min', '44min', '50min', '19min', '21min', '23min', '24min', '45min', '54min', '58min', '58min', '55min', '38min', '52min', '24min', '59min', '38min', '50min', '43min', '54min', '43min', '38min', '50min', '54min', '21min', '52min', '20min', '45min', '45min', '1h 1min', '50min', '45min', '22min', '1h 0min', '59min', '47min', '34min', '50min']
# 100

# %% [markdown]
# ## **Creating TV Show DataFrame**

# %%
 # Write Your Code here
info = {
    'tv_title' : tv_shows_title,
    'release_year': tv_shows_year,
    'genre_list': tv_genre_list,
    'imdb_rating' : tv_imdb_rating,
    'tv_prod_country':tv_production_country,
    'tv_stream':tv_Streaming_Provider,
    'runtime': tv_runtime,
    'tv_show_url':tv_show_url
}
tv_df = pd.DataFrame(info)

# %%
tv_df
# Out:
#                        tv_title  release_year  \
# 0               Mirzapur (2018)          2018
# 1    House of the Dragon (2022)          2022
# 2               The Boys (2019)          2019
# 3              Panchayat (2020)          2020
# 4             Sweet Home (2020)          2020
# ..                          ...           ...
# 95              Red Swan (2024)          2024
# 96              The Wire (2002)          2002
# 97               Lucifer (2016)          2016
# 98                           NA          2020
# 99           Yellowstone (2018)          2018
#
#                                            genre_list  imdb_rating  \
# 0   Action & Adventure, Drama, Crime, Mystery & Th...   8.5  (86k)
# 1   Drama, Action & Adventure, Science-Fiction, Fa...  8.4  (422k)
# 2   Action & Adventure, Science-Fiction, Comedy, C...  8.7  (703k)
# 3                                       Comedy, Drama   9.0  (95k)
# 4   Science-Fiction, Fantasy, Horror, Mystery & Th...   7.3  (33k)
# ...

# %%
# make a csv file
tv_df.to_csv('tv_file.csv')

Datasets_Drive_Link ='https://drive.google.com/drive/folders/1hiIwJxY86Y-fDFB7mPYN2m5h10fJH-zo?usp=sharing'

# %% [markdown]
# [tv_file](https://drive.google.com/file/d/1CpQdiyMySB0nD8CpIbK6i3SeVKaqn9ZB/view?usp=sharing)

# %% [markdown]
# ## **Task 2 :- Data Filtering & Analysis**

# %% [markdown]
# ###**Movies**

# %%
# Write Your Code here
# first we copy the code where we do manipulation
movie_df1 = movie_df.copy()
movie_df1
# Out:
#                                  movies_title  movies_year  \
# 0                             Maharaja (2024)         2024
# 1                                 Kill (2024)         2024
# 2                        Kalki 2898-AD (2024)         2024
# 3                               Munjya (2024)         2024
# 4     The Gangster, the Cop, the Devil (2019)         2019
# ..                                        ...          ...
# 105                    The Instigators (2024)         2024
# 106                          Daughters (2024)         2024
# 107                          The Union (2024)         2024
# 108                         Nice Girls (2024)         2024
# 109         Secret Lives of Orangutans (2024)         2024
#
#                                           movies_genre movies_imdb_rating  \
# 0    Crime, Drama, Mystery & Thriller, Action & Adv...         8.7  (31k)
# 1    Mystery & Thriller, Action & Adventure, Crime,...         8.7  (31k)
# ...

# %%
# basic check row and column
movie_df1.shape
# Out:
# (110, 8)

# %%
# lets see data types and null counts
movie_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movies_title        110 non-null    object
#  1   movies_year         110 non-null    int64
#  2   movies_genre        110 non-null    object
#  3   movies_imdb_rating  110 non-null    object
#  4   movies_runtime      110 non-null    object
#  5   production_country  110 non-null    object
#  6   streaming_service   110 non-null    object
#  7   movie_link          110 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 7.0+ KB

# %%
#Changing column data types to required data types
movie_df1['movies_imdb_rating'] = movie_df1['movies_imdb_rating'].str.extract(r'(\d+\.\d+)').astype(float)

# %%
movie_df1.describe(include=['object','float'])
# Out:
#             movies_title movies_genre  movies_imdb_rating movies_runtime  \
# count                110          110          110.000000            110
# unique               105           84                 NaN             65
# top      Maharaja (2024)        Drama                 NaN       2h 30min
# freq                   2            6                 NaN              5
# mean                 NaN          NaN            7.196364            NaN
# std                  NaN          NaN            1.191247            NaN
# min                  NaN          NaN            3.300000            NaN
# 25%                  NaN          NaN            6.700000            NaN
# 50%                  NaN          NaN            7.450000            NaN
# 75%                  NaN          NaN            8.100000            NaN
# max                  NaN          NaN            8.900000            NaN
#
#        production_country  streaming_service  \
# ...

# %%
#Checking for Duplicates
movie_df1.duplicated().sum()
# Out:
# 5

# %%
#Dropping Duplicates
movie_df1=movie_df1.drop_duplicates()
movie_df1
# Out:
#                                  movies_title  movies_year  \
# 0                             Maharaja (2024)         2024
# 1                                 Kill (2024)         2024
# 2                        Kalki 2898-AD (2024)         2024
# 3                               Munjya (2024)         2024
# 4     The Gangster, the Cop, the Devil (2019)         2019
# ..                                        ...          ...
# 105                    The Instigators (2024)         2024
# 106                          Daughters (2024)         2024
# 107                          The Union (2024)         2024
# 108                         Nice Girls (2024)         2024
# 109         Secret Lives of Orangutans (2024)         2024
#
#                                           movies_genre  movies_imdb_rating  \
# 0    Crime, Drama, Mystery & Thriller, Action & Adv...                 8.7
# 1    Mystery & Thriller, Action & Adventure, Crime,...                 8.7
# ...

# %%
# Filter the DataFrame
filtered_movie_df1 = movie_df1[
    (movie_df1['movies_year'] >= 2024 - 2) &  # Released in the last 2 years
    (movie_df1['movies_imdb_rating'] >= 7)                     # IMDb rating of 7 or higher
]
filtered_movie_df1.shape
# Out:
# (43, 8)

# %% [markdown]
# ###**TV Shows**

# %%
# Write Your Code here
# first we copy the code where we do manipulation
tv_df1 = tv_df.copy()
tv_df1
# Out:
#                        tv_title  release_year  \
# 0               Mirzapur (2018)          2018
# 1    House of the Dragon (2022)          2022
# 2               The Boys (2019)          2019
# 3              Panchayat (2020)          2020
# 4             Sweet Home (2020)          2020
# ..                          ...           ...
# 95              Red Swan (2024)          2024
# 96              The Wire (2002)          2002
# 97               Lucifer (2016)          2016
# 98                           NA          2020
# 99           Yellowstone (2018)          2018
#
#                                            genre_list  imdb_rating  \
# 0   Action & Adventure, Drama, Crime, Mystery & Th...   8.5  (86k)
# 1   Drama, Action & Adventure, Science-Fiction, Fa...  8.4  (422k)
# 2   Action & Adventure, Science-Fiction, Comedy, C...  8.7  (703k)
# 3                                       Comedy, Drama   9.0  (95k)
# 4   Science-Fiction, Fantasy, Horror, Mystery & Th...   7.3  (33k)
# ...

# %%
# basic check row and column
tv_df1.shape
# Out:
# (100, 8)

# %%
# lets see data types and null counts
tv_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tv_title         100 non-null    object
#  1   release_year     100 non-null    int64
#  2   genre_list       100 non-null    object
#  3   imdb_rating      100 non-null    object
#  4   tv_prod_country  100 non-null    object
#  5   tv_stream        100 non-null    object
#  6   runtime          100 non-null    object
#  7   tv_show_url      100 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 6.4+ KB

# %%
#Changing column data types to required data types
tv_df1['imdb_rating'] = tv_df1['imdb_rating'].str.extract(r'(\d+\.\d+)').astype(float)

# %%
# statistical report
tv_df1.describe(include=['object','float'])
# Out:
#                 tv_title genre_list  imdb_rating tv_prod_country tv_stream  \
# count                100        100    99.000000             100       100
# unique               100         80          NaN              15        18
# top      Mirzapur (2018)      Drama          NaN   United States   Netflix
# freq                   1          6          NaN              47        29
# mean                 NaN        NaN     7.841414             NaN       NaN
# std                  NaN        NaN     1.152461             NaN       NaN
# min                  NaN        NaN     3.400000             NaN       NaN
# 25%                  NaN        NaN     7.300000             NaN       NaN
# 50%                  NaN        NaN     8.200000             NaN       NaN
# 75%                  NaN        NaN     8.700000             NaN       NaN
# max                  NaN        NaN     9.500000             NaN       NaN
#
#        runtime                                    tv_show_url
# ...

# %%
#Checking for Duplicates
tv_df1.duplicated().sum()
# Out:
# 0

# %%
# drop column which have 90 % of data are missing
#tv_df1.drop('tv_stream',axis=1,inplace=True)

# %%
# Filter the DataFrame
filtered_tv_df1 = tv_df1[
    (tv_df1['release_year'] >= 2024 - 2) &  # Released in the last 2 years
    (tv_df1['imdb_rating'] >= 7)                     # IMDb rating of 7 or higher
]
filtered_tv_df1.shape
# Out:
# (20, 8)

# %% [markdown]
# ## **Calculating Mean IMDB Ratings for both Movies and Tv Shows**

# %%
# find mean rating of imdb rating of Movies
movies_mean_rating = filtered_movie_df1['movies_imdb_rating'].mean()

# Print the mean rating of movies
print(f"Movies mean rating: {movies_mean_rating}")
# Out:
# Movies mean rating: 7.862790697674418

# %%
# find mean rating of imdb rating
tv_mean_rating = filtered_tv_df1['imdb_rating'].mean()

# print mean rating of tv shows
print(f"Tv shows mean rating: {tv_mean_rating}")
# Out:
# Tv shows mean rating: 7.764999999999999

# %% [markdown]
# ## **Analyzing Top Genres**

# %% [markdown]
# ###**Movies**

# %%
from collections import Counter

# Function to split genres and strip spaces
def split_genres(genre_string):
    genres = genre_string.replace('&', ',').split(',')
    return [genre.strip() for genre in genres]

# Apply function to the genre_list column and flatten the list of lists
all_genres = [genre for sublist in filtered_movie_df1['movies_genre'].apply(split_genres) for genre in sublist]

# Count the occurrences of each genre
genre_counts = Counter(all_genres)

# Convert the counter to a DataFrame for easy sorting and printing
genre_counts_df = pd.DataFrame.from_dict(genre_counts, orient='index', columns=['count']).sort_values(by='count', ascending=False)

# Print the top 5 genres with the highest number of Movies
print("Top 5 genres with the highest number of Movies:")
print(genre_counts_df.head(5))
# Out:
# Top 5 genres with the highest number of Movies:
#            count
# Drama         33
# Action        18
# Adventure     18
# Mystery       17
# Thriller      17

# %%
#Let's Visvalize it using word cloud
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(genre_counts)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ###**Tv Shows**

# %%
from collections import Counter

# Function to split genres and strip spaces
def split_genres(genre_string):
    genres = genre_string.replace('&', ',').split(',')
    return [genre.strip() for genre in genres]

# Apply function to the genre_list column and flatten the list of lists
all_genres = [genre for sublist in filtered_tv_df1['genre_list'].apply(split_genres) for genre in sublist]

# Count the occurrences of each genre
genre_counts = Counter(all_genres)

# Convert the counter to a DataFrame for easy sorting and printing
genre_counts_df = pd.DataFrame.from_dict(genre_counts, orient='index', columns=['count']).sort_values(by='count', ascending=False)

# Print the top 5 genres with the highest number of TV shows
print("Top 5 genres with the highest number of TV shows:")
print(genre_counts_df.head(5))
# Out:
# Top 5 genres with the highest number of TV shows:
#                  count
# Drama               19
# Science-Fiction      8
# Crime                7
# Adventure            7
# Thriller             7

# %%
#Let's Visvalize it using word cloud
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(genre_counts)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## **Finding Predominant Streaming Service**

# %% [markdown]
# ###**Movies**

# %%
# Write Your Code here
from collections import Counter

# Function to split Streaming Services and strip spaces
def split_services(Streaming_string):
    Streaming_Services = Streaming_string.replace('&', ',').split(',')
    return [Service.strip() for Service in Streaming_Services]

# Apply function to the streaming_service column and flatten the list of lists
all_Services = [Service for sublist in filtered_movie_df1['streaming_service'].apply(split_services) for Service in sublist]

# Count the occurrences of each streaming_service
service_counts = Counter(all_Services)

# Convert the counter to a DataFrame for easy sorting and printing
Service_counts_df = pd.DataFrame.from_dict(service_counts, orient='index', columns=['count']).sort_values(by='count', ascending=False)

# Print the top 5 streaming services with the highest number of Movies
print("Top 5 streaming services with the highest number of Movies:")
print(Service_counts_df.head(5))
# Out:
# Top 5 streaming services with the highest number of Movies:
#                     count
# Apple TV+              43
# Apple TV               17
# Amazon Video           13
# Amazon Prime Video     11
# Netflix                 8

# %%
#Let's Visvalize it using word cloud
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(service_counts)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ###**TV Shows**

# %%
# Write Your Code here
from collections import Counter

# Function to split Streaming Services and strip spaces
def split_services(Streaming_string):
    Streaming_Services = Streaming_string.replace('&', ',').split(',')
    return [Service.strip() for Service in Streaming_Services]

# Apply function to the streaming_service column and flatten the list of lists
all_Services = [Service for sublist in filtered_tv_df1['tv_stream'].apply(split_services) for Service in sublist]

# Count the occurrences of each streaming_service
service_counts = Counter(all_Services)

# Convert the counter to a DataFrame for easy sorting and printing
Service_counts_df = pd.DataFrame.from_dict(service_counts, orient='index', columns=['count']).sort_values(by='count', ascending=False)

# Print the top 5 streaming services with the highest number of Tv shows
print("Top 5 streaming services with the highest number of Tv shows:")
print(Service_counts_df.head(5))
# Out:
# Top 5 streaming services with the highest number of Tv shows:
#                     count
# Netflix                 7
# Amazon Prime Video      6
# Jio Cinema              2
# Hotstar                 2
# Apple TV Plus           2

# %%
#Let's Visvalize it using word cloud
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(service_counts)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## **Task 3 :- Data Export**

# %%
#saving final dataframe as Final Data in csv format
# final filtered data of tv_shows
filtered_tv_df = filtered_tv_df1.to_csv('filtered_tv_df.csv')

# final filtered data of movies
filtered_movie_df = filtered_movie_df1.to_csv('filtered_movie_df.csv')

Filtered_Datasets_Drive_Link ='https://drive.google.com/drive/folders/1YYrJ1IyqNuJj4rqhl-q6yGHqOU-Xc7nr?usp=sharing'

# %% [markdown]
# [filtered_movie_df](https://drive.google.com/file/d/1tIfaHnzA4cRadTGalZsU9HPQNOl9wNmi/view?usp=sharing)

# %% [markdown]
# [filtered_tv_df](https://drive.google.com/file/d/15HONGIzSscdFjDvt1vyAcfESEPOFfY6v/view?usp=sharing)

# %% [markdown]
# # **Dataset Drive Link (View Access with Anyone) -**

# %% [markdown]
# # ***Congratulations!!! You have completed your Assignment.***
